# %%
import pandas as pd

# %%
student = pd.read_csv("pract1.csv")
marks = pd.read_csv("prac2.csv")

# %%
results = pd.merge(student,marks,on = "StudentID",how = "left")

# %%
print(results)
# Out:
#    StudentID name  marks
# 0          1    A   88.0
# 1          2    B   70.0
# 2          3    C   90.0
# 3          4    D   89.0
# 4          5    E    NaN

# %%
result =pd.merge(student,marks,on ="StudentID",how = "inner")
print(result)
# Out:
#    StudentID name  marks
# 0          1    A     88
# 1          2    B     70
# 2          3    C     90
# 3          4    D     89
